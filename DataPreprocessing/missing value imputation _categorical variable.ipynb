# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\singh\Downloads\train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
cat_var=df.select_dtypes(['object'])

# %%
cat_var
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1455       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
# ...

# %%
cat_var.isnull().sum()/cat_var.shape[0]*100
# Out:
# MSZoning          0.000000
# Street            0.000000
# Alley            93.767123
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType        0.547945
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# BsmtFinType2      2.602740
# Heating           0.000000
# HeatingQC         0.000000
# CentralAir        0.000000
# Electrical        0.068493
# KitchenQual       0.000000
# Functional        0.000000
# FireplaceQu      47.260274
# GarageType        5.547945
# ...

# %%
#same as above
miss_val_per=cat_var.isnull().mean()*100

# %%
drop_vars=miss_val_per[miss_val_per>20].keys()

# %%
drop_vars
# Out:
# Index(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')

# %%
cat_var.drop(columns=drop_vars,axis=1,inplace=True)

# %%
cat_var.shape
# Out:
# (1460, 38)

# %%
isnull_per=cat_var.isnull().mean()*100

# %%
miss_ver=isnull_per[isnull_per>0].keys()
miss_ver
# Out:
# Index(['MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinType2', 'Electrical', 'GarageType', 'GarageFinish',
#        'GarageQual', 'GarageCond'],
#       dtype='object')

# %% [markdown]
# # we are filling NaN with global constant

# %%
cat_var['MasVnrType'].fillna('missing',inplace=True)

# %%
cat_var['MasVnrType'].value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# missing      8
# Name: MasVnrType, dtype: int64

# %%
cat_var['MasVnrType'].isna().sum()
# Out:
# 0

# %% [markdown]
# # we are filling NaN with MODE

# %% [raw]
# This is for single column

# %%
isnull_per=cat_var.isnull().mean()*100
miss_ver=isnull_per[isnull_per>0].keys()
miss_ver
# Out:
# Index(['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond'],
#       dtype='object')

# %%
# Finding the mode of particular column
cat_var['BsmtQual'].mode()
# Out:
# 0    TA
# Name: BsmtQual, dtype: object

# %%
cat_var['BsmtQual'].value_counts()
# Out:
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64

# %%
cat_var['BsmtQual'].fillna(cat_var['BsmtQual'].mode()[0],inplace=True)

# %%
print(cat_var['BsmtQual'].mode()[0])
# Out:
# TA

# %%
cat_var['BsmtQual'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # For all column

# %%
isnull_per=cat_var.isnull().mean()*100
miss_ver=isnull_per[isnull_per>0].keys()
miss_ver
# Out:
# Index(['BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond'],
#       dtype='object')

# %%
for var in miss_ver:
    cat_var[var].fillna(cat_var[var].mode()[0],inplace=True)
    print(var, '=',cat_var[var].mode()[0])
# Out:
# BsmtCond = TA
# BsmtExposure = No
# BsmtFinType1 = Unf
# BsmtFinType2 = Unf
# Electrical = SBrkr
# GarageType = Attchd
# GarageFinish = Unf
# GarageQual = TA
# GarageCond = TA

# %%
cat_var.isnull().sum().sum()
# Out:
# 0

# %%
plt.hist(cat_var[var],label='impute')
plt.hist(df[var].dropna(),label='original')
plt.legend()

# %%
# for all columns
plt.figure(figsize=(16,9))
for i,var in enumerate(miss_ver):
    plt.subplot(3,3,i+1)
    plt.hist(cat_var[var],label='impute')
    plt.hist(df[var].dropna(),label='original',alpha=0.8)
    plt.legend()

# %% [markdown]
# # Updating the data we got in original dataset

# %%
df.update(cat_var)
df.drop(columns=drop_vars,inplace=True)

# %%
df.select_dtypes(['object']).isnull().sum()
# Out:
# MSZoning         0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinType2     0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# KitchenQual      0
# Functional       0
# GarageType       0
# GarageFinish     0
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# SaleType         0
# SaleCondition    0
# dtype: int64
